# %%
# Install the latest Tensorflow version.
# !pip3 install --quiet "tensorflow>=1.7"
# Install TF-Hub.
# !pip3 install --quiet tensorflow-hub
# !pip3 install --quiet seaborn

# %%
# !pip install contractions
# !pip install beautifulsoup4
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/52/52/a15f0fb338a462045c7c87a35dbaeda11738c45aa9d2f5c76ac191d6adff/contractions-0.0.17-py2.py3-none-any.whl
# Installing collected packages: contractions
# Successfully installed contractions-0.0.17
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import pandas as pd
import time
import contractions #pip install contractions
from bs4 import BeautifulSoup #pip install beautifulsoup4
import unicodedata
import re

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/movie_reviews.csv.bz2', compression='bz2')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
# review       50000 non-null object
# sentiment    50000 non-null object
# dtypes: object(2)
# memory usage: 781.3+ KB

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['sentiment'] = [1 if sentiment == 'positive' else 0 for sentiment in df['sentiment'].values]
df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %% [markdown]
# ## Creating Datasets for Training, Testing and Validation:

# %%
reviews = df['review'].values
labels = df['sentiment'].values

train_reviews = reviews[:30000]
train_labels = labels[:30000]

test_reviews = reviews[30000:40000]
test_labels = labels[30000:40000]

val_reviews = reviews[45000:]
val_labels = labels[45000:]

train_reviews.shape, test_reviews.shape, val_reviews.shape,
# Out:
# ((30000,), (10000,), (5000,))

# %%
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    [s.extract() for s in soup(['iframe', 'script'])]
    text_ = soup.get_text()
    text_ = re.sub(r'[\r|\n|\r\n]+', '\n', text_)
    return text_

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
def expand_contractions(text):
    return contractions.fix(text)

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-Z0-9\s]' if not remove_digits else r'[^a-zA-Z\s]'
    text = re.sub(pattern, '', text)
    return text

# %%
def clean_doc(document):
    
    # strip HTML
    doc = strip_html_tags(document)
    
    # lower case
    doc = doc.lower()
    
    # remove extra newlines (often might be present in really noisy text)
    doc = doc.translate(document.maketrans("\n\t\r", "   "))
    
    # remove accented characters
    doc = remove_accented_chars(doc)
    
    # expand contractions    
    doc = expand_contractions(doc)
               
    # remove special characters and\or digits    
    # insert spaces between special characters to isolate them    
    special_char_pattern = re.compile(r'([{.(-)!}])')
    doc = special_char_pattern.sub(" \\1 ", doc)
    doc = remove_special_characters(doc, remove_digits=True)  
        
    # remove extra whitespace
    doc = re.sub(' +', ' ', doc)
    doc = doc.strip()
    
    return doc


clean_corpus = np.vectorize(clean_doc)

# %% [markdown]
# ## Preprocessing the Text:

# %%
train_reviews = clean_corpus(train_reviews)
val_reviews = clean_corpus(val_reviews)
test_reviews = clean_corpus(test_reviews)

# %% [markdown]
# ## Preparing the Training:

# %%
# Training input on the whole training set with no limit on training epochs.
train_input = tf.estimator.inputs.numpy_input_fn({'sentence': train_reviews}, train_labels, batch_size=256, num_epochs=None, shuffle=True)

# %%
# Prediction on the whole training set.
predict_train = tf.estimator.inputs.numpy_input_fn({'sentence': train_reviews}, train_labels, shuffle=False)

# %%
# Prediction on the whole validation set.
predict_val = tf.estimator.inputs.numpy_input_fn({'sentence': val_reviews}, val_labels, shuffle=False)

# %%
# Prediction on the test set.
predict_test = tf.estimator.inputs.numpy_input_fn({'sentence': test_reviews}, test_labels, shuffle=False)

# %% [markdown]
# ## Loading Embeddings from Universal Sentence Encoder:

# %%
embeddings = hub.text_embedding_column(key='sentence', module_spec="https://tfhub.dev/google/universal-sentence-encoder/2", trainable=False)
# Out:
# INFO:tensorflow:Using /tmp/tfhub_modules to cache modules.
# INFO:tensorflow:Downloading TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/2'.
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 788.00MB
# INFO:tensorflow:Downloaded https://tfhub.dev/google/universal-sentence-encoder/2, Total size: 993.27MB
# INFO:tensorflow:Downloaded TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/2'.

# %% [markdown]
# ## Creating the Classifier:

# %%
cls = tf.estimator.DNNClassifier(
          hidden_units=[512, 128],
          feature_columns=[embeddings],
          n_classes=2,
          activation_fn=tf.nn.relu,
          dropout=0.2,
          optimizer=tf.train.AdagradOptimizer(learning_rate=0.005))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp0a7vg04h
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp0a7vg04h', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb48877d240>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# ## Training the model:

# %%
# %%time
tf.logging.set_verbosity(tf.logging.ERROR)

epochs = 1000
step = 100
for s in range(0, epochs+1, step):
    print()
    print('-'*150)
    print('Epoch =', s)
    ini_time = time.time()
    cls.train(input_fn=train_input, steps=step)
    total_time = time.time() - ini_time
    print('Train Time (s):', total_time)
    print('Metrics for Train):', cls.evaluate(input_fn=predict_train))
    print('Metrics for Validation):', cls.evaluate(input_fn=predict_val))
# Out:
# ----------------------------------------------------------------------------------------------------
# Training for step = 0
# Train Time (s): 85.70678925514221
# Metrics (Train): {'accuracy': 0.83463335, 'accuracy_baseline': 0.5005, 'auc': 0.9252298, 'auc_precision_recall': 0.925236, 'average_loss': 0.36300963, 'label/mean': 0.5005, 'loss': 46.341656, 'precision': 0.8832139, 'prediction/mean': 0.4462625, 'recall': 0.7716284, 'global_step': 100}
# Metrics (Validation): {'accuracy': 0.8336, 'accuracy_baseline': 0.50600004, 'auc': 0.9234706, 'auc_precision_recall': 0.9208938, 'average_loss': 0.36624637, 'label/mean': 0.494, 'loss': 45.780796, 'precision': 0.88164026, 'prediction/mean': 0.443118, 'recall': 0.7659919, 'global_step': 100}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 100
# Train Time (s): 82.87584829330444
# Metrics (Train): {'accuracy': 0.84506667, 'accuracy_baseline': 0.5005, 'auc': 0.9297993, 'auc_precision_recall': 0.9299148, 'average_loss': 0.34645143, 'label/mean': 0.5005, 'loss': 44.227844, 'precision': 0.8784958, 'prediction/mean': 0.4600715, 'recall': 0.8012654, 'global_step': 200}
# Metrics (Validation): {'accuracy': 0.8422, 'accuracy_baseline': 0.50600004, 'auc': 0.9274026, 'auc_precision_recall': 0.924976, 'average_loss': 0.3517918, 'label/mean': 0.494, 'loss': 43.973976, 'precision': 0.87843317, 'prediction/mean': 0.45579413, 'recall': 0.78987855, 'global_step': 200}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 200
# Train Time (s): 82.40753698348999
# Metrics (Train): {'accuracy': 0.8526667, 'accuracy_baseline': 0.5005, 'auc': 0.9315836, 'auc_precision_recall': 0.9316437, 'average_loss': 0.334904, 'label/mean': 0.5005, 'loss': 42.7537, 'precision': 0.863116, 'prediction/mean': 0.488971, 'recall': 0.83862805, 'global_step': 300}
# Metrics (Validation): {'accuracy': 0.8508, 'accuracy_baseline': 0.50600004, 'auc': 0.92865837, 'auc_precision_recall': 0.9257389, 'average_loss': 0.3423662, 'label/mean': 0.494, 'loss': 42.795773, 'precision': 0.86157715, 'prediction/mean': 0.48444033, 'recall': 0.83157897, 'global_step': 300}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 300
# Train Time (s): 83.9992687702179
# Metrics (Train): {'accuracy': 0.85573334, 'accuracy_baseline': 0.5005, 'auc': 0.9334961, 'auc_precision_recall': 0.93384016, 'average_loss': 0.32997045, 'label/mean': 0.5005, 'loss': 42.123886, 'precision': 0.8516154, 'prediction/mean': 0.50632036, 'recall': 0.86193806, 'global_step': 400}
# Metrics (Validation): {'accuracy': 0.8508, 'accuracy_baseline': 0.50600004, 'auc': 0.9296134, 'auc_precision_recall': 0.92689806, 'average_loss': 0.33949062, 'label/mean': 0.494, 'loss': 42.43633, 'precision': 0.8489879, 'prediction/mean': 0.5021609, 'recall': 0.8489879, 'global_step': 400}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 400
# Train Time (s): 83.81255602836609
# Metrics (Train): {'accuracy': 0.8579, 'accuracy_baseline': 0.5005, 'auc': 0.93499684, 'auc_precision_recall': 0.9350821, 'average_loss': 0.32639915, 'label/mean': 0.5005, 'loss': 41.667976, 'precision': 0.85077643, 'prediction/mean': 0.51076764, 'recall': 0.86839825, 'global_step': 500}
# Metrics (Validation): {'accuracy': 0.852, 'accuracy_baseline': 0.50600004, 'auc': 0.9310585, 'auc_precision_recall': 0.9283587, 'average_loss': 0.33628622, 'label/mean': 0.494, 'loss': 42.035774, 'precision': 0.8473896, 'prediction/mean': 0.5063163, 'recall': 0.854251, 'global_step': 500}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 500
# Train Time (s): 82.45590043067932
# Metrics (Train): {'accuracy': 0.85836667, 'accuracy_baseline': 0.5005, 'auc': 0.93629384, 'auc_precision_recall': 0.9364598, 'average_loss': 0.32741708, 'label/mean': 0.5005, 'loss': 41.797928, 'precision': 0.8371117, 'prediction/mean': 0.53107417, 'recall': 0.8902431, 'global_step': 600}
# Metrics (Validation): {'accuracy': 0.8526, 'accuracy_baseline': 0.50600004, 'auc': 0.9316056, 'auc_precision_recall': 0.92912173, 'average_loss': 0.33925155, 'label/mean': 0.494, 'loss': 42.406445, 'precision': 0.83161116, 'prediction/mean': 0.52704763, 'recall': 0.8797571, 'global_step': 600}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 600
# Train Time (s): 83.15762448310852
# Metrics (Train): {'accuracy': 0.86076665, 'accuracy_baseline': 0.5005, 'auc': 0.93776983, 'auc_precision_recall': 0.9378726, 'average_loss': 0.3192718, 'label/mean': 0.5005, 'loss': 40.758102, 'precision': 0.85539085, 'prediction/mean': 0.50831693, 'recall': 0.8686647, 'global_step': 700}
# Metrics (Validation): {'accuracy': 0.8568, 'accuracy_baseline': 0.50600004, 'auc': 0.9328485, 'auc_precision_recall': 0.93022805, 'average_loss': 0.33176732, 'label/mean': 0.494, 'loss': 41.470917, 'precision': 0.85506076, 'prediction/mean': 0.50313425, 'recall': 0.85506076, 'global_step': 700}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 700
# Train Time (s): 83.44287371635437
# Metrics (Train): {'accuracy': 0.86226666, 'accuracy_baseline': 0.5005, 'auc': 0.9389906, 'auc_precision_recall': 0.938891, 'average_loss': 0.3159721, 'label/mean': 0.5005, 'loss': 40.336864, 'precision': 0.86571676, 'prediction/mean': 0.49626547, 'recall': 0.85787547, 'global_step': 800}
# Metrics (Validation): {'accuracy': 0.8546, 'accuracy_baseline': 0.50600004, 'auc': 0.9336863, 'auc_precision_recall': 0.9311586, 'average_loss': 0.32983088, 'label/mean': 0.494, 'loss': 41.22886, 'precision': 0.86206895, 'prediction/mean': 0.4909053, 'recall': 0.840081, 'global_step': 800}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 800
# Train Time (s): 83.20907711982727
# Metrics (Train): {'accuracy': 0.8637667, 'accuracy_baseline': 0.5005, 'auc': 0.9402503, 'auc_precision_recall': 0.94048727, 'average_loss': 0.31480968, 'label/mean': 0.5005, 'loss': 40.18847, 'precision': 0.8494947, 'prediction/mean': 0.51886964, 'recall': 0.88451546, 'global_step': 900}
# Metrics (Validation): {'accuracy': 0.8558, 'accuracy_baseline': 0.50600004, 'auc': 0.93341416, 'auc_precision_recall': 0.9311147, 'average_loss': 0.33141056, 'label/mean': 0.494, 'loss': 41.42632, 'precision': 0.84280676, 'prediction/mean': 0.51447934, 'recall': 0.8704454, 'global_step': 900}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 900
# Train Time (s): 84.39755725860596
# Metrics (Train): {'accuracy': 0.86653334, 'accuracy_baseline': 0.5005, 'auc': 0.94160867, 'auc_precision_recall': 0.9415913, 'average_loss': 0.31024686, 'label/mean': 0.5005, 'loss': 39.60598, 'precision': 0.8543021, 'prediction/mean': 0.51553917, 'recall': 0.8841159, 'global_step': 1000}
# Metrics (Validation): {'accuracy': 0.8566, 'accuracy_baseline': 0.50600004, 'auc': 0.9346722, 'auc_precision_recall': 0.93249446, 'average_loss': 0.32807717, 'label/mean': 0.494, 'loss': 41.009647, 'precision': 0.8463058, 'prediction/mean': 0.5110898, 'recall': 0.86720645, 'global_step': 1000}
#
# ----------------------------------------------------------------------------------------------------
# Training for step = 1000
# Train Time (s): 85.02146744728088
# Metrics (Train): {'accuracy': 0.86553335, 'accuracy_baseline': 0.5005, 'auc': 0.94297737, 'auc_precision_recall': 0.9429562, 'average_loss': 0.3091043, 'label/mean': 0.5005, 'loss': 39.46012, 'precision': 0.8847852, 'prediction/mean': 0.4752403, 'recall': 0.84082586, 'global_step': 1100}
# Metrics (Validation): {'accuracy': 0.8574, 'accuracy_baseline': 0.50600004, 'auc': 0.93529004, 'auc_precision_recall': 0.9328685, 'average_loss': 0.32854372, 'label/mean': 0.494, 'loss': 41.067966, 'precision': 0.88079756, 'prediction/mean': 0.4697365, 'recall': 0.82267207, 'global_step': 1100}

# %% [markdown]
# ## Testing the model:

# %%
cls.evaluate(input_fn=predict_test)
# Out:
# {'accuracy': 0.8572,
#  'accuracy_baseline': 0.5022,
#  'auc': 0.93549216,
#  'auc_precision_recall': 0.93376917,
#  'average_loss': 0.32665488,
#  'global_step': 1100,
#  'label/mean': 0.4978,
#  'loss': 41.34872,
#  'precision': 0.8707185,
#  'prediction/mean': 0.47735542,
#  'recall': 0.83748496}
