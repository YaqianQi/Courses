# %% [markdown]
# # Scraping Yahoo Finance

# %% [markdown]
# ## Week 7. Practice Programming Assignment 1

# %% [markdown]
# In this assignment you are required to look at historical data for 30 companies from [Dow Jones Index](https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average). Tickers for companies from the index can be found in *dow_jones_tickers.txt*. For each company you should get historical daily stock prices for 2019 from https://finance.yahoo.com/, and then use the data to answer the questions you will find below.

# %% [markdown]
# ###### Import coursera grader tools

# %%
import sys
import numpy as np
sys.path.append("..")
import grading
grader = grading.Grader(assignment_key="FpZrXMbETcuStX7z6jFv2Q", 
                      all_parts=["RbP2k", "LLRai", "hgIbw", "Tx3OG", "Y05pG",
                                 "lFPeF", "htUtf", "Xri0I", "4JfUm", "oD7pP"])

# %%
# token expires every 30 min
COURSERA_EMAIL = "yatsi@edu.hse.ru"### YOUR EMAIL HERE
COURSERA_TOKEN = "4RPD2NBQetU4LEQy"### YOUR TOKEN

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ### Coding part

# %%
# you can start your web-scraping here

# %%
dow_jones_companies = []

with open('dow_jones_tickers.txt') as f:
    for ticker in f:
        dow_jones_companies.append(ticker.strip())
import numpy as np 
np.array(dow_jones_companies)
# Out:
# array(['AXP', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'XOM', 'GS', 'HD',
#        'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT',
#        'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'RTX', 'VZ', 'V', 'WBA', 'WMT',
#        'DIS', 'DOW'], dtype='<U4')

# %%
import yfinance as yf
data = pd.DataFrame()
for ticket in dow_jones_companies:
    print(ticket)
    stock = yf.download(ticket,'2019-01-01','2020-01-01')
    stock['ticket'] = ticket
    data = pd.concat([data, stock], axis=0)
data
# Out:
# AXP
# [*********************100%***********************]  1 of 1 completed
# AAPL
# [*********************100%***********************]  1 of 1 completed
# BA
# [*********************100%***********************]  1 of 1 completed
# CAT
# [*********************100%***********************]  1 of 1 completed
# CSCO
# [*********************100%***********************]  1 of 1 completed
# CVX
# [*********************100%***********************]  1 of 1 completed
# XOM
# [*********************100%***********************]  1 of 1 completed
# GS
# [*********************100%***********************]  1 of 1 completed
# HD
# [*********************100%***********************]  1 of 1 completed
# IBM
# [*********************100%***********************]  1 of 1 completed
# INTC
# [*********************100%***********************]  1 of 1 completed
# JNJ
# [*********************100%***********************]  1 of 1 completed
# KO
# [*********************100%***********************]  1 of 1 completed
# JPM
# [*********************100%***********************]  1 of 1 completed
# MCD
# [*********************100%***********************]  1 of 1 completed
# MMM
# [*********************100%***********************]  1 of 1 completed
# MRK
# [*********************100%***********************]  1 of 1 completed
# MSFT
# [*********************100%***********************]  1 of 1 completed
# NKE
# [*********************100%***********************]  1 of 1 completed
# PFE
# [*********************100%***********************]  1 of 1 completed
# PG
# [*********************100%***********************]  1 of 1 completed
# TRV
# [*********************100%***********************]  1 of 1 completed
# UNH
# [*********************100%***********************]  1 of 1 completed
# RTX
# [*********************100%***********************]  1 of 1 completed
# VZ
# [*********************100%***********************]  1 of 1 completed
# V
# [*********************100%***********************]  1 of 1 completed
# WBA
# [*********************100%***********************]  1 of 1 completed
# WMT
# [*********************100%***********************]  1 of 1 completed
# DIS
# [*********************100%***********************]  1 of 1 completed
# DOW
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-
# 2019-11-25   5073700    DOW
# 2019-11-26   4643800    DOW
# 2019-11-27   3926000    DOW
# 2019-11-29   1887600    DOW
# 2019-12-02   3349500    DOW
# 2019-12-03   3950100    DOW
# 2019-12-04   3791400    DOW
# 2019-12-05   2692600    DOW
# 2019-12-06   2818800    DOW
# 2019-12-09   2377200    DOW
# 2019-12-10   2609700    DOW
# 2019-12-11   3253300    DOW
# 2019-12-12   2882300    DOW
# 2019-12-13   3198600    DOW
# 2019-12-16   4040000    DOW
# 2019-12-17   2665300    DOW
# 2019-12-18   3659100    DOW
# 2019-12-19   3356000    DOW
# 2019-12-20  10476700    DOW
# 2019-12-23   2678600    DOW
# 2019-12-24    926200    DOW
# 2019-12-26   1909600    DOW
# 2019-12-27   1688500    DOW
# 2019-12-30   1943300    DOW
# 2019-12-31   2145700    DOW
#
# [7507 rows x 7 columns]

# %%
price_changes = []
for ticket in dow_jones_companies:
    stock_data = data[data["ticket"]==ticket]
    price_change = (stock_data['Close'][-1]/stock_data['Open'][0]-1) * 100
    price_changes.append(price_change)
price_changes
# Out:
# [32.563084878249796,
#  89.58615472504773,
#  3.0266634777588175,
#  19.067962693902764,
#  13.434248981003027,
#  12.269430079802301,
#  3.6080183522342546,
#  39.91966781097525,
#  28.678331414483658,
#  19.66787851955283,
#  30.221931388900103,
#  13.845305204350812,
#  17.916489334166275,
#  45.28400034413777,
#  12.656060934247426,
#  -6.069645783579647,
#  20.799569454494748,
#  58.412849938589304,
#  39.181201105030624,
#  -9.13728832167382,
#  37.20751752254792,
#  16.563111276107655,
#  19.991841218909446,
#  42.41156938341035,
#  9.330487344558392,
#  44.538456843449524,
#  -12.261902139840908,
#  29.681358718248397,
#  33.792790864318654,
#  3.7535536345712384]

# %%
price_change_df = pd.DataFrame()
price_change_df['ticket'] = dow_jones_companies
price_change_df['price_change'] = price_changes

# %% [markdown]
# <br><br>
#
# ### Questions
#
# <br><br>
#
# **Question 1.** What is the average change of price over the year (in %)?
#
# *Note 1*. The opening price is the price at which a stock first trades upon the opening of an exchange on a trading day.
#
# *Note 2*. The closing price for any stock is the final price at which it trades during regular market hours on any given day.
#
# *Note 3*. Here by the price change we going to mean a ratio of a closing price in the last day of the period to an opening price in the first day of that period, subtracted one and multiplied by 100.
#
# Example: if a price of a stock in day 1 opened at \\$100, and its close price in the last day was \\$120, then the price change during the period is: $$\left(\dfrac{120}{100}-1\right) * 100 = (1.2 - 1) * 100=20.$$
#
# The price grew by 20%.

# %%
answer_part_1 = np.mean(price_changes)

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("RbP2k", answer_part_1)

# %% [markdown]
# <br>
#
# **Question 2.** What company's stock price grew the most (in %)? Enter ticker of the company as an answer)

# %%
price_change_df.sort_values('price_change', ascending=False).reset_index(drop=True)['ticket'].iloc[0]
# Out:
# 'AAPL'

# %%
answer_part_2 = 'AAPL'

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("LLRai", answer_part_2)

# %% [markdown]
# <br>
#
# **Question 3.** What company's stock lost in price the most (in %)? Enter ticker of the company as an answer

# %%
answer_part_3 = price_change_df.sort_values('price_change', ascending=False).\
reset_index(drop=True)['ticket'].iloc[-1]

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("hgIbw", answer_part_3)

# %% [markdown]
# <br>
#
# **Question 4.** What company had the largest summary volume over the year? Enter ticker of the company as an answer

# %%
data.groupby('ticket').sum()['Volume'].reset_index().\
sort_values('Volume', ascending=False).reset_index(drop=True)['ticket'].iloc[0]
# Out:
# 'AAPL'

# %%
answer_part_4 = 'AAPL'

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("Tx3OG", answer_part_4)

# %% [markdown]
# <br>
#
# **Question 5.** What is the biggest stock price daily increase (in %)? Enter the number

# %%
data['daily_ptc'] = (data['Close']/data['Open'] - 1) * 100
max(data['daily_ptc'])
# Out:
# 7.741002936516583

# %%
answer_part_5 = 7.741002936516583

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("Y05pG", answer_part_5)

# %% [markdown]
# <br><br>
#
# **Question 6.** What is the company that had the biggest stock price daily increase? Enter ticker of the company as an answer

# %%
data[data['daily_ptc'] == max(data['daily_ptc'])]['ticket']
# Out:
# Date
# 2019-03-11    BA
# Name: ticket, dtype: object

# %%
answer_part_6 =  'BA'

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("lFPeF", answer_part_6)

# %% [markdown]
# <br>
#
# **Question 7.** What is the biggest stock price daily decrease (in %)? Enter the number

# %%
answer_part_7 =  min(data['daily_ptc'])

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("htUtf", answer_part_7)

# %% [markdown]
# <br>
#
# **Question 8.** What is the company that had the biggest stock price daily decrese (in %)? Enter ticker of the company as an answer

# %%
data[data['daily_ptc'] == min(data['daily_ptc'])]['ticket']
# Out:
# Date
# 2019-04-16    UNH
# Name: ticket, dtype: object

# %%
answer_part_8 = 'UNH'

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("Xri0I", answer_part_8)

# %% [markdown]
# <br>
#
# **Question 9.** What was the best month for all companies (i.e. average monthly price increase was the best)? Enter one of the following: January, February, March, April, May, June, July, August, September, October, November, December

# %%
#data = data.reset_index()

data['month'] = pd.DatetimeIndex(data['Date']).month

data.groupby("month").mean()['daily_ptc'].reset_index().sort_values("daily_ptc", ascending=False)
# Out:
#     month  daily_ptc
# 0       1   0.292917
# 1       2   0.168678
# 10     11   0.074571
# 3       4   0.049942
# 5       6   0.044545
# 4       5   0.040277
# 6       7  -0.005626
# 8       9  -0.009960
# 11     12  -0.025820
# 9      10  -0.029283
# 2       3  -0.038319
# 7       8  -0.178294

# %%
answer_part_9 = "January"

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("4JfUm", answer_part_9)

# %% [markdown]
# <br>
#
# **Question 10.** What was the worst month for all companies (i.e. average monthly price increase was the worst)? Enter one of the following: January, February, March, April, May, June, July, August, September, October, November, December

# %%
answer_part_10 = "May"

# %%
# Setting our answers to grader. Do not change!
grader.set_answer("oD7pP", answer_part_10)

# %% [markdown]
# <br>
# <br>
#
# ### Submitting answers

# %%
# you can make submission with answers so far to check yourself at this stage
grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!
